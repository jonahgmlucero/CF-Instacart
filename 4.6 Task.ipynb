# %% [markdown]
# ## 4.6 Task

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#import orders_products_combined
orders_products_combined = pd.read_pickle(r'/Users/jonahsnewmacbook/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined.pkl')

# %%
#creating a path
path=r'/Users/jonahsnewmacbook/Instacart Basket Analysis'

# %%
#checking for the shape
orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
#the imported dataframe and the exported dataframe are the same

# %% [markdown]
# ### combining orders_products_cobined with df_prods

# %%
df_prods= pd.read_csv(r'/Users/jonahsnewmacbook/Instacart Basket Analysis/02 Data/Prepared Data/products_checked.csv')

# %%
#checking for the columns of both dataframes
orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_timestamp  days_since_prior_order  product_id  add_to_cart_order  \
# 0                8                     0.0         196                  1
# 1                8                     0.0       14084                  2
# 2                8                     0.0       12427                  3
# 3                8                     0.0       26088                  4
# 4                8                     0.0       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# ...

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#converting df_prods into pickle
df_prods.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_prods_pickle.pkl'))

# %%
#importing df_prods_pickle.pkl
df_prods= pd.read_pickle(r'/Users/jonahsnewmacbook/Instacart Basket Analysis/02 Data/Prepared Data/df_prods_pickle.pkl')

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#now merging using product_id
df_merged= df_prods.merge(orders_products_combined, on ='product_id', indicator='exists')

# %%
df_merged.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id  order_number  \
# 0             19     5.8          1987   3139998      138            28
# 1             19     5.8          1989   1977647      138            30
# 2             19     5.8         11433    389851      709             2
# 3             19     5.8         12198    652770      764             1
# 4             19     5.8         12200   1813452      764             3
#
#    orders_day_of_week  order_timestamp  days_since_prior_order  \
# 0                   6               11                     3.0
# ...

# %%
#gonna do some cleaning a bit: dropping columns that are not important
df_merged = df_merged.drop(columns=['Unnamed: 0_x', 'Unnamed: 0_y'])

# %%
#exporting the dataframe
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
